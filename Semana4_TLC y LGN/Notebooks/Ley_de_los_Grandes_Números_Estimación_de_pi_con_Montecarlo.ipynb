# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Estadistica_y_Probabilidad_para-CD-/blob/main/Semana3/Ley_de_los_Grandes_N%C3%BAmeros_Estimaci%C3%B3n_de_pi_con_Montecarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def calcula_pi(n, print_results=True):
  a, b = -1., 1.
  xs = np.random.uniform(a, b, n) 
  ys = np.random.uniform(a, b, n) 

  en_circulo = np.where((np.sqrt(xs**2 + ys**2)<=1), 1, 0)

  puntos_circulo = (en_circulo==1).sum()
  puntos_cuadrado = n

  pi = 4* puntos_circulo/ puntos_cuadrado
  error = abs(np.pi-pi)

  if print_results==True:
    plt.figure(figsize=(6,6))
    sns.scatterplot( x=xs, y=ys, s = 4,hue=en_circulo )
    plt.show()

    print('pi =', pi)
    print('error =', error)

  return pi

# %%
calcula_pi(2000)
# Out:
# pi = 3.182
# error = 0.040407346410206824
# 3.182

# %%
ns = range(10, 10000)
pi_est = []
for n in ns:
  pi = calcula_pi(n, print_results=False)
  pi_est.append(pi)

#Gráfica estimación de  pi vs pi
plt.figure(figsize=(16, 6))
plt.plot(ns, pi_est, color='g')
plt.axhline(y=np.pi, color='black', ls='--')
plt.xlim(0, ns[-1])
plt.ylim(2.2, 4)
plt.xlabel('n')
plt.ylabel('Estimación de pi')
plt.title('Estimación de pi según cantidad de puntos')
plt.show()

# %% [markdown]
# # ¿Podemos usar una distribución gaussiana o una distribución de laplace para la generación de nuestros puntos aleatorios?

# %%
n = 100000
a, b = -1., 1.
xs= np.random.uniform(a, b, n) 
ys= np.random.uniform(a, b, n) 

sns.jointplot(xs, ys, kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
xs.var()
# Out:
# 0.3341251294992454

# %%
mu, sigma = 0., 1/3 
xs = np.random.normal(mu, sigma, n)
ys = np.random.normal(mu, sigma, n)

sns.jointplot(xs, ys, kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
xs.var()
# Out:
# 0.11067062352799995

# %%
mu, scale = 0., 1/7 
xs = np.random.laplace(mu, scale, n)
ys = np.random.laplace(mu, scale, n)

sns.jointplot(xs, ys, kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
