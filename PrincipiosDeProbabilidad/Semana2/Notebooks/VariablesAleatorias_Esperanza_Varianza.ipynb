# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Estadistica_y_Probabilidad_para-CD-/blob/main/PrincipiosDeProbabilidad/Semana2/Notebooks/VariablesAleatorias_Esperanza_Varianza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Librerías y funciones

# %%
import numpy as np
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %matplotlib inline

# %%
def burbujas_espacio_probabilidad(elementos, probabilidad):
  '''
  Función que muestra grafico de burbuja de un espacio de probabilidad de una
  variable aleatoria discreta

  elementos: lista, vector o serie que contiene los posibles elementos
  probabilidad: lista, vector o serie que contiene la probabilidad de cada
                elemento
  nombre_var: objeto de texto con el nombre de la variable aleatoria
  '''


  n = len(elementos)
  X = np.random.randint(1, 8000,n)
  Y = np.random.randint(1, 8000,n)
  P = np.array(probabilidad)
  color = np.random.rand(n)
  titulo = 'Espacio de probabilidad'
  plt.scatter(x=X, y=Y, s=P*10000,
              c = color, alpha=0.5)
  margen =2500
  plt.xlim(min(X)-margen, max(X)+margen)
  plt.ylim(min(X)-margen,max(X)+margen)
  plt.title(titulo)

  #Mostrar valores de los elementos y sus probabilidades
  for e, p, x, y in zip(elementos,P,X,Y):
    plt.annotate("{}".format(e),
                 xy=(x, y),
                 ha="center", va="center")
    #plt.annotate(e ,xy=(x, y), xytext=(0,np.sqrt(p*10000)/2.+5),
     #            textcoords="offset points", ha="center", va="bottom")

  #Eliminar texto y marcas de los ejes
  ax = plt.gca( )
  ax.axes.xaxis.set_ticks([])
  ax.axes.yaxis.set_ticks([])
  plt.show()

# %% [markdown]
# # Lanzar un dado

# %% [markdown]
# ## Espacio de probabilidad

# %%
W = np.array([1, 2, 3, 4, 5, 6])   #omega
P = np.array([1/6, 1/6, 1/6, 1/6, 1/6, 1/6])

# %%
np.random.seed(15)
burbujas_espacio_probabilidad(W, P)

# %%
sns.barplot(x= W, y = P)
plt.show()

# %% [markdown]
# ## Esperanza matemática y varianza de la distribución de probabilidad (Ley de probabilidad)

# %%
esperanza = 0
for elemento, probabilidad in zip(W, P):
  esperanza += elemento * probabilidad
print('la esperanza matemática de lanzar un dado es:', esperanza)
# Out:
# la esperanza matemática de lanzar un dado es: 3.5

# %%
varianza = 0
for elemento, probabilidad in zip(W, P):
  varianza += ((elemento-esperanza)**2)*probabilidad
varianza
# Out:
# np.float64(2.9166666666666665)

# %% [markdown]
# ## Promedio y varianza de la distribución empírica
#
# Tirar n número de veces el dado y obtener la media y la varianza

# %%
n=10000

dado1 = []
for i in range(n):
  tiro_d1 = np.random.choice(W)
  dado1.append(tiro_d1)

media =sum(dado1)/n
varianza = sum([(x-media)**2 for x in dado1])/n

print('media: {}\nvarianza: {}\n\n'.format(media, varianza))

sns.histplot( x = np.array(dado1), discrete=True, stat = 'probability')
plt.show()
# Out:
# media: 3.4933
# varianza: 2.9175551100003982

# %% [markdown]
# ### Ejercicio 1
#
# a) Calcular la esperanza matemática y la varianza de un jugador al tirar un dado, de acuerdo a la siguiente regla:
#  - gana \$5 dolares si  tirar obtiene un 1, 2 o 3
#  - gana \$10 dólares si  tirar obtiene un 4 o 5
#  - pierde \$25 dólares si al tirar obtiene un 6
#
# b) Calcular la media y la varianza empirica al simular que un jugador juega 10, 100 y 1000 y 10000 mil veces.
#
# c) Explicar las diferencias entre la esperanza y varianza calculadas en el punto (a) y los cálculos de la media y varianza empirica del punto (b)

# %% [markdown]
# # Lanzar dos dados

# %% [markdown]
# ## Espacio de probabilidad de las combinaciones al tirar dos dados

# %%
dado = [1, 2, 3, 4, 5, 6]

#obtener las 36 combinaciones
combinaciones = list(itertools.product(dado, repeat=2))
probabilidades = list(itertools.repeat(1/36,36))

# %%
np.random.seed(22)
burbujas_espacio_probabilidad(combinaciones, probabilidades)

# %%
grafica = sns.barplot(x= [str(i) for i in combinaciones], y = probabilidades )
grafica.set_xticklabels(grafica.get_xticklabels(), rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-383883846.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   grafica.set_xticklabels(grafica.get_xticklabels(), rotation=90)

# %% [markdown]
# # Suma de dos dados

# %%
dos_dados = pd.DataFrame(combinaciones)
dos_dados.columns = ['dado1', 'dado2']
dos_dados['probabilidad']= probabilidades
dos_dados['suma'] = dos_dados['dado1'] + dos_dados['dado2']

# %%
dos_dados
# Out:
#     dado1  dado2  probabilidad  suma
# 0       1      1      0.027778     2
# 1       1      2      0.027778     3
# 2       1      3      0.027778     4
# 3       1      4      0.027778     5
# 4       1      5      0.027778     6
# 5       1      6      0.027778     7
# 6       2      1      0.027778     3
# 7       2      2      0.027778     4
# 8       2      3      0.027778     5
# 9       2      4      0.027778     6
# 10      2      5      0.027778     7
# 11      2      6      0.027778     8
# 12      3      1      0.027778     4
# 13      3      2      0.027778     5
# 14      3      3      0.027778     6
# 15      3      4      0.027778     7
# 16      3      5      0.027778     8
# 17      3      6      0.027778     9
# 18      4      1      0.027778     5
# 19      4      2      0.027778     6
# 20      4      3      0.027778     7
# 21      4      4      0.027778     8
# 22      4      5      0.027778     9
# 23      4      6      0.027778    10
# 24      5      1      0.027778     6
# 25      5      2      0.027778     7
# 26      5      3      0.027778     8
# 27      5      4      0.027778     9
# 28      5      5      0.027778    10
# 29      5      6      0.027778    11
# 30      6      1      0.027778     7
# 31      6      2      0.027778     8
# 32      6      3      0.027778     9
# 33      6      4      0.027778    10
# 34      6      5      0.027778    11
# 35      6      6      0.027778    12

# %% [markdown]
# ## Espacio de probabilidad

# %%
Ley_P_suma = pd.DataFrame(dos_dados['suma'].value_counts(sort=False)/36)
Ley_P_suma.reset_index(inplace=True)
Ley_P_suma.columns=['elementos', 'probabilidad']

Ley_P_suma
# Out:
#     elementos  probabilidad
# 0           2      0.027778
# 1           3      0.055556
# 2           4      0.083333
# 3           5      0.111111
# 4           6      0.138889
# 5           7      0.166667
# 6           8      0.138889
# 7           9      0.111111
# 8          10      0.083333
# 9          11      0.055556
# 10         12      0.027778

# %%
np.random.seed(10)
burbujas_espacio_probabilidad(Ley_P_suma['elementos'],
                              Ley_P_suma['probabilidad'])

# %%
sns.barplot(x=Ley_P_suma['elementos'], y=Ley_P_suma['probabilidad'] )
plt.show()

# %% [markdown]
# ## Esperanza matemática y varianza

# %%
Ley_P_suma
# Out:
#     elementos  probabilidad
# 0           2      0.027778
# 1           3      0.055556
# 2           4      0.083333
# 3           5      0.111111
# 4           6      0.138889
# 5           7      0.166667
# 6           8      0.138889
# 7           9      0.111111
# 8          10      0.083333
# 9          11      0.055556
# 10         12      0.027778

# %%
esperanza = (Ley_P_suma['elementos'] * Ley_P_suma['probabilidad']).sum()
round(esperanza,2)
# Out:
# np.float64(7.0)

# %%
varianza = (((Ley_P_suma['elementos']-esperanza)**2)*Ley_P_suma['probabilidad']).sum()
round(varianza,2)
# Out:
# 5.83

# %% [markdown]
# ## Media muestral

# %%
n =1000
X = [1,2,3,4,5,6]

dado1 = []
dado2 = []
suma = []    #variable aleatoria ¿distribución?

for _ in range (n):
  tiro_d1 = np.random.choice(X)
  tiro_d2 = np.random.choice(X)

  dado1.append(tiro_d1)
  dado2.append(tiro_d2)
  suma.append(tiro_d1 + tiro_d2)
suma[-20:]
# Out:
# [7, 9, 3, 9, 5, 5, 6, 6, 5, 6, 6, 5, 11, 6, 8, 8, 2, 6, 7, 7]

# %%
media =sum(suma)/n
varianza = sum([(x-media)**2 for x in suma])/n

print('media: {:.2f}\nvarianza: {:.2f}\n\n'.format(media, varianza))

sns.histplot( x = suma, discrete=True, stat = 'probability')
plt.show()
# Out:
# media: 7.04
# varianza: 5.82

# %% [markdown]
# # Multiplicacion de dos dados

# %% [markdown]
# ## Espacio de probabilidad

# %%
dos_dados['multiplicacion'] = dos_dados['dado1'] * dos_dados['dado2']
dos_dados
# Out:
#     dado1  dado2  probabilidad  suma  multiplicacion
# 0       1      1      0.027778     2               1
# 1       1      2      0.027778     3               2
# 2       1      3      0.027778     4               3
# 3       1      4      0.027778     5               4
# 4       1      5      0.027778     6               5
# 5       1      6      0.027778     7               6
# 6       2      1      0.027778     3               2
# 7       2      2      0.027778     4               4
# 8       2      3      0.027778     5               6
# 9       2      4      0.027778     6               8
# 10      2      5      0.027778     7              10
# 11      2      6      0.027778     8              12
# 12      3      1      0.027778     4               3
# 13      3      2      0.027778     5               6
# 14      3      3      0.027778     6               9
# 15      3      4      0.027778     7              12
# 16      3      5      0.027778     8              15
# 17      3      6      0.027778     9              18
# 18      4      1      0.027778     5               4
# 19      4      2      0.027778     6               8
# 20      4      3      0.027778     7              12
# 21      4      4      0.027778     8              16
# 22      4      5      0.027778     9              20
# 23      4      6      0.027778    10              24
# 24      5      1      0.027778     6               5
# 25      5      2      0.027778     7              10
# 26      5      3      0.027778     8              15
# 27      5      4      0.027778     9              20
# 28      5      5      0.027778    10              25
# 29      5      6      0.027778    11              30
# 30      6      1      0.027778     7               6
# 31      6      2      0.027778     8              12
# 32      6      3      0.027778     9              18
# 33      6      4      0.027778    10              24
# 34      6      5      0.027778    11              30
# 35      6      6      0.027778    12              36

# %%
Ley_P_multiplicacion = pd.DataFrame(dos_dados['multiplicacion'].value_counts(sort=False)/36)

Ley_P_multiplicacion.reset_index(inplace=True)
Ley_P_multiplicacion.columns=['elementos', 'probabilidad']

Ley_P_multiplicacion
# Out:
#     elementos  probabilidad
# 0           1      0.027778
# 1           2      0.055556
# 2           3      0.055556
# 3           4      0.083333
# 4           5      0.055556
# 5           6      0.111111
# 6           8      0.055556
# 7          10      0.055556
# 8          12      0.111111
# 9           9      0.027778
# 10         15      0.055556
# 11         18      0.055556
# 12         16      0.027778
# 13         20      0.055556
# 14         24      0.055556
# 15         25      0.027778
# 16         30      0.055556
# 17         36      0.027778

# %%
Ley_P_multiplicacion.probabilidad.sum()
# Out:
# 1.0

# %%
np.random.seed(10)
burbujas_espacio_probabilidad(Ley_P_multiplicacion['elementos'],
                              Ley_P_multiplicacion['probabilidad'])

# %%
sns.barplot(x=Ley_P_multiplicacion['elementos'], y=Ley_P_multiplicacion['probabilidad'] )
plt.show()

# %% [markdown]
# ## Esperanza matemática y varianza

# %%
esperanza = (Ley_P_multiplicacion['elementos'] * Ley_P_multiplicacion['probabilidad']).sum()
round(esperanza,2)
# Out:
# 12.25

# %%
varianza = (((Ley_P_multiplicacion['elementos']-esperanza)**2)*Ley_P_multiplicacion['probabilidad']).sum()
round(varianza,2)
# Out:
# 79.97

# %% [markdown]
# ## Media muestral

# %%
n =100000
X = [1,2,3,4,5,6]

dado1 = []
dado2 = []
multiplicacion = []    #variable aleatoria ¿distribución?

for _ in range (n):
  tiro_d1 = np.random.choice(X)
  tiro_d2 = np.random.choice(X)

  dado1.append(tiro_d1)
  dado2.append(tiro_d2)
  multiplicacion.append(tiro_d1 * tiro_d2)

multiplicacion[-20:]
# Out:
# [5, 15, 30, 12, 3, 12, 24, 9, 24, 10, 9, 3, 20, 30, 10, 24, 30, 12, 16, 5]

# %%
media =sum(multiplicacion)/n
varianza = sum([(x-media)**2 for x in multiplicacion])/n

print('media: {:.2f}\nvarianza: {:.2f}\n\n'.format(media, varianza))

sns.histplot( x = multiplicacion, discrete=True, stat = 'probability')
plt.show()
# Out:
# media: 12.30
# varianza: 80.43
