# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Estadistica_y_Probabilidad_para-CD-/blob/main/Semana2/Notebooks/Gausianas_Multivariadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
medias = [1.72, 68]
covarianza = [[11, 9], [9, 10]]

altura, peso = np.random.multivariate_normal(mean = medias, cov = covarianza, size = 10000).T
sns.jointplot(x=altura, y=peso, kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()

# %%
n = 10000
x1 = np.random.normal(loc=0, scale = 1, size = n)
y1 = np.random.normal(loc=0, scale = 1, size=n)
sns.jointplot( x=x1, y= y1, kind = 'scatter', color = 'darkcyan', s = 2  )
M_covarianza1 = np.cov(x1, y1)
print(M_covarianza1.round(2))
plt.show()
# Out:
# [[1.02 0.  ]
#  [0.   1.  ]]

# %%
x2  = np.random.normal(loc=5, scale=1.2, size = n)
y2 = 6 - 2 * x2 + np.random.normal(size=n)
sns.jointplot(x=x2, y= y2, kind = 'scatter', color = 'darkcyan', s = 2 )
M_covarianza2 = np.cov(x2, y2)
print(M_covarianza2.round(2))
plt.show()
# Out:
# [[ 1.48 -2.94]
#  [-2.94  6.84]]

# %% [markdown]
# podríamos generar las coordenadas de puntos aleatoreos por medio de la distribución normal multivariada, ingresando las medias y la matriz de covarianza

# %%
medias = np.array((x2.mean(), y2.mean()))
medias.shape, M_covarianza2.shape
# Out:
# ((2,), (2, 2))

# %%
coordenadas = np.random.multivariate_normal(mean = medias, cov = M_covarianza2, size = n)
coordenadas.shape
# Out:
# (10000, 2)

# %%
sns.jointplot(x=coordenadas[:,0], y=coordenadas[:,1], kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()
