# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Estadistica_y_Probabilidad_para-CD-/blob/main/Semana2/Simulaci%C3%B3n_de_variables_aleatorias_continuas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import kurtosis
import matplotlib.pyplot as plt

# %% [markdown]
# # Simulación uniforme

# %%
# generación de una muestra aleatoria con distribución de la place
a, b = 0., 1.
s = np.random.uniform(a, b, 1000)
plt.hist( s, bins=30,  density=True)
plt.show()

# %%
9/5  #Curtosis de una distribución normal
# Out:
# 1.8

# %%
kurtosis(s, fisher=False)
# Out:
# 1.8002280483770476

# %% [markdown]
# ## Distribución de probabilidad gaussiana
#
# $p(x)= \frac{1}{b-a}$

# %%
plt.hlines(1/(b-a), xmin=a, xmax=b, color='orange')
plt.show()

# %%
plt.hist( s, bins=30, density=True)
plt.hlines(1/(b-a), xmin=a, xmax=b, color='orange')
plt.show()

# %% [markdown]
# # Simulación gaussiana

# %%
# generación de una muestra aleatoria con distribución de la place
mu, sigma = 0., 1.
s = np.random.normal(mu, sigma, 1000)
plt.hist( s, bins=30,  density=True)
plt.show()

# %%
kurtosis(s, fisher=False)
# Out:
# 2.912340892408859

# %% [markdown]
# ## Distribución de probabilidad gaussiana
#
# $f(x)= \frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}} $

# %%
x = np.arange(-3., 3., .01)
pdf = 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (x - mu)**2 / (2 * sigma**2) )  # función de la distribución de probabilidad de gauss
plt.plot(x, pdf)
plt.show()

# %%
plt.hist( s, bins=30, density=True)
plt.plot(x, pdf)
plt.show()

# %% [markdown]
# # Simulación laplace

# %%
# generación de una muestra aleatoria con distribución de la place
loc, scale = 0., 1
s = np.random.laplace(loc, scale, 10000)
plt.hist( s, bins=30,  density=True)
plt.show()
print('Curtosis:', kurtosis(s, fisher=False))
# Out:
# Curtosis: 5.83614041856258

# %% [markdown]
# ## Distribución de probabilidad de laplace
#
# $f(x;\mu,\lambda)= \frac{1}{2\lambda}\exp({-\frac{\lvert{x-\mu}\rvert}{\lambda}}) $

# %%
x = np.arange(-8., 8., .01)
pdf = np.exp(-abs(x-loc)/scale)/(2.*scale)  # función de la distribución de probabilidad de laplace
plt.plot(x, pdf)
plt.show()

# %%
plt.hist( s, bins=30, density=True)
plt.plot(x, pdf)
plt.show()
